# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha-Sisodia/DeepAlgoMinds/blob/main/26.Minimum_Common_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://leetcode.com/problems/minimum-common-value/description/

# %%
# Method 1 - Using two pointers
class Solution(object):
    def getCommon(self, nums1, nums2):
        p1 = 0
        p2 = 0
        n1 = len(nums1)
        n2 = len(nums2)
        while p1 < n1 and p2 < n2:
            if nums1[p1] == nums2[p2]:
                return nums1[p1]
            elif nums1[p1] < nums2[p2]:
                p1 += 1
            else:
                p2 += 1
        return -1

# %%
# Method 2 - using Binary search

class Solution(object):
    def getCommon(self, nums1, nums2):
        n1 = len(nums1)
        n2 = len(nums2)
        for i in range(n1):
            start = 0
            end = n2 - 1
            while start <= end:
                mid = (start+end)//2
                if nums1[i] < nums2[mid]:
                    end = mid - 1
                elif nums1[i] > nums2[mid]:
                    start = mid + 1
                else:
                    return nums1[i]
        return -1
