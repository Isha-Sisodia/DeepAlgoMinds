# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha-Sisodia/DeepAlgoMinds/blob/main/35.Count_Squares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.geeksforgeeks.org/problems/count-squares3649/1

# %%
class Solution:
    def countSquares(self, n):
        # code here
        count = 0
        for i in range(n):
            if i*i < n:
                count += 1
            else:
                break
        return count-1    #because we need to eliminate 0*0 < n condition

# %%
# Using while loop
# More cleaner Version
n = 9
i=1
while i*i < n:
  i+=1
print(i-1)
# Out:
# 2
