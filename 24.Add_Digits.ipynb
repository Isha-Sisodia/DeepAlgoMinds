# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha-Sisodia/DeepAlgoMinds/blob/main/24.Add_Digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://leetcode.com/problems/add-digits/description/

# %%
def addDigits(n):
  while n > 9:
    sum_digit = 0
    while n > 0:
      digit = n % 10
      n = n//10
      sum_digit += digit
    n = sum_digit
  return n

addDigits(23)
# Out:
# 5
