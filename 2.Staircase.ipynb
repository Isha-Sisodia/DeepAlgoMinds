# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha-Sisodia/DeepAlgoMinds/blob/main/2.Staircase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link - https://www.hackerrank.com/challenges/staircase/problem?isFullScreen=true

# %%
def staircase(n):
    for i in range(1, n + 1):
        print(" " * (n - i) + "#" * i)

n = int(input("Enter n: "))
staircase(n)
# Out:
# Enter n: 4
#    #
#   ##
#  ###
# ####

# %%
# before above we can try this easy one -
n = 5
for i in range(1,n+1):
  print("#" * i)
# Out:
# #
# ##
# ###
# ####
# #####

# %% [markdown]
# Submission Link - https://www.hackerrank.com/challenges/staircase/problem
